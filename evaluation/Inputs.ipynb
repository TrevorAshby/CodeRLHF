# %%
import pandas as pd
import numpy as np

problemList = []
inputExample = []

problemList.append("p02402")
inputExample.append('''5
10 1 5 4 17''')
problemList.append("p03316")
inputExample.append('''12''')

problemList.append("p02995")
inputExample.append('''4 9 2 3''')

problemList.append("p03129")
inputExample.append('''3 2''')

problemList.append("p02612")
inputExample.append('''1900''')

problemList.append("p02400")
inputExample.append('''2''')

problemList.append("p00001")
inputExample.append('''1819
2003
876
2840
1723
1673
3776
2848
1592
922''')

problemList.append("p00007")
inputExample.append('''5''')

problemList.append("p00018")
inputExample.append('''3 6 9 7 5''')

problemList.append("p00729")
inputExample.append('''4 2
10
775 1 1 1
780 4 2 1
790 2 1 1
800 2 1 0
810 3 1 1
820 1 1 0
825 3 1 0
860 1 1 1
870 4 2 0
880 1 1 0
1
780 870 1
13 15
12
540 12 13 1
600 12 13 0
650 13 15 1
660 12 15 1
665 11 13 1
670 13 15 0
675 11 13 0
680 12 15 0
1000 11 14 1
1060 12 14 1
1060 11 14 0
1080 12 14 0
3
540 700 13
600 1000 15
1000 1200 11
1 1
2
600 1 1 1
700 1 1 0
5
540 600 1
550 650 1
610 620 1
650 750 1
700 800 1
0 0''')

problemList.append("p01102")
inputExample.append('''print"hello";print123
print"hello";print123
read"B1input";solve;output;''')

problemList.append("p02258")
inputExample.append('''6
5
3
1
3
4
3''')

problemList.append("p02261")
inputExample.append('''5
H4 C9 S4 D2 C3''')

problemList.append("p02263")
inputExample.append('''1 2 +''')

problemList.append("p02280")
inputExample.append('''9
0 1 4
1 2 3
2 -1 -1
3 -1 -1
4 5 8
5 6 7
6 -1 -1
7 -1 -1
8 -1 -1''')

problemList.append("p02315")
inputExample.append('''4 5
4 2
5 2
2 1
8 3''')

problemList.append("p02317")
inputExample.append('''5
5
1
3
2
4''')

problemList.append("p02370")
inputExample.append('''6 6
0 1
1 2
3 1
3 4
4 5
5 2''')

problemList.append("p02383")
inputExample.append('''1 2 4 8 16 32
SE''')

problemList.append("p02388")
inputExample.append('''2''')

problemList.append("p02389")
inputExample.append('''3 5''')

problemList.append("p02390")
inputExample.append('''46979''')

problemList.append("p02392")
inputExample.append('''1 3 8''')

problemList.append("p02401")
inputExample.append('''1 + 2
56 - 18
13 * 2
100 / 10
27 + 81
0 ? 0''')

problemList.append("p02403")
inputExample.append('''3 4
5 6
2 2
0 0''')

problemList.append("p02404")
inputExample.append('''3 4
5 6
3 3
0 0''')

problemList.append("p02410")
inputExample.append('''3 4
1 2 0 1
0 3 0 1
4 1 1 0
1
2
3
0''')

problemList.append("p02411")
inputExample.append('''40 42 -1
20 30 -1
0 2 -1
-1 -1 -1''')

problemList.append("p02416")
inputExample.append('''123
55
1000
0''')

problemList.append("p02472")
inputExample.append('''5 8''')

problemList.append("p02546")
inputExample.append('''apple''')

problemList.append("p02547")
inputExample.append('''5
1 2
6 6
4 4
3 3
3 2''')

problemList.append("p02548")
inputExample.append('''3''')

problemList.append("p02572")
inputExample.append('''3
1 2 3''')

problemList.append("p02576")
inputExample.append('''20 12 6''')

problemList.append("p02577")
inputExample.append('''123456789''')

problemList.append("p02578")
inputExample.append('''5
2 1 5 4 3''')

problemList.append("p02584")
inputExample.append('''6 2 4''')

problemList.append("p02594")
inputExample.append('''25''')

problemList.append("p02596")
inputExample.append('''101''')

problemList.append("p02597")
inputExample.append('''4
WWRR''')

problemList.append("p02598")
inputExample.append('''2 3
7 9''')

problemList.append("p02599")
inputExample.append('''4 3
1 2 1 3
1 3
2 4
3 3''')

problemList.append("p02600")
inputExample.append('''725''')

problemList.append("p02601")
inputExample.append('''A B C
K''')

problemList.append("p02603")
inputExample.append('''7
100 130 130 130 115 115 150''')


problemList.append("p02607")
inputExample.append('''5
1 3 4 5 7''')

problemList.append("p02608")
inputExample.append('''20''')

problemList.append("p04043")
inputExample.append('''5 5 7''')

problemList.append("p04033")
inputExample.append('''1 3''')

# %%
a = []

c = zip(problemList,inputExample)
a.append(problemList)
a.append(inputExample)

df = pd.DataFrame(data=problemList)
da = pd.DataFrame(data=inputExample)
dff = pd.DataFrame(data=c, columns=["a","b"])
print(dff)
dff.to_feather("file.feather")
# Out:
#          a                                                  b
# 0   p02402                                     5\n10 1 5 4 17
# 1   p03316                                                 12
# 2   p02995                                            4 9 2 3
# 3   p03129                                                3 2
# 4   p02612                                               1900
# 5   p02400                                                  2
# 6   p00001  1819\n2003\n876\n2840\n1723\n1673\n3776\n2848\...
# 7   p00007                                                  5
# 8   p00018                                          3 6 9 7 5
# 9   p00729  4 2\n10\n775 1 1 1\n780 4 2 1\n790 2 1 1\n800 ...
# 10  p01102  print"hello";print123\nprint"hello";print123\n...
# 11  p02258                                6\n5\n3\n1\n3\n4\n3
# 12  p02261                                  5\nH4 C9 S4 D2 C3
# 13  p02263                                              1 2 +
# ...

# %%
b = ['p03618', 'p02923', 'p03424', 'p03109', 'p02577', 'p03714', 'p03315', 'p02939', 'p03434', 'p03760', 'p02693', 'p02641', 'p03575', 'p03103', 'p02765', 'p03026', 'p02678', 'p03472', 'p03045', 'p03796', 'p03378', 'p03011', 'p02392', 'p03075', 'p02781', 'p02856', 'p00001', 'p02861', 'p03339', 'p02860', 'p03013', 'p02410', 'p03370', 'p03102', 'p02887', 'p03479', 'p02404', 'p02981', 'p02726', 'p02646', 'p02950', 'p03220', 'p03164', 'p02675', 'p03852', 'p03502', 'p03624', 'p03372', 'p03171', 'p03394', 'p02886', 'p03644', 'p02700', 'p02851', 'p02628', 'p02682', 'p04029', 'p03987', 'p02803', 'p03087', 'p04043', 'p02912', 'p03776', 'p02657', 'p03107', 'p03970', 'p03241', 'p02837', 'p01102', 'p02389', 'p02619', 'p02836', 'p03455', 'p03448', 'p02729', 'p03547', 'p02694', 'p03351', 'p02681', 'p02262', 'p02759', 'p02598', 'p03359', 'p02711', 'p03501', 'p03186', 'p02608', 'p03814', 'p03317', 'p02871', 'p03265', 'p03525', 'p04033', 'p02578', 'p03209', 'p03425', 'p03338', 'p02802', 'p03071', 'p02793', 'p03773', 'p02778', 'p02922', 'p03544', 'p03135', 'p02640', 'p02933', 'p04005', 'p02796', 'p02723', 'p03494', 'p02547', 'p02280